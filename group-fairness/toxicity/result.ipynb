# %%
import re
import pandas as pd
with open('summary/toxicity1.out') as f:
    res = f.read()
f.close()
pd.set_option('display.max_rows', None)

# %%
res = re.split('\n', res)
res = res[:-1]
results = [eval(r) for r in res]
results = pd.DataFrame(results)
results
# Out:
# 359580  0.020890        0.319444        0.085938
# 44       0.799896  0.389764  0.010445        0.347222        0.046875
# 45       0.827095  0.322178  0.023631        0.277778        0.078125
# 46       0.807899  0.366470  0.017732        0.326389        0.066406
# 47       0.787555  0.409449  0.015442        0.375000        0.054688
# 48       0.711100  0.572178  0.005621        0.555556        0.019531
# 49       0.839589  0.301181  0.019641        0.215278        0.078125
# 50       0.844282  0.275591  0.035846        0.180556        0.175781
# 51       0.832969  0.315289  0.018773        0.222222        0.085938
# 52       0.847761  0.272310  0.032167        0.284722        0.101562
# 53       0.796747  0.386483  0.020022        0.326389        0.074219
# 54       0.792974  0.401247  0.012804        0.375000        0.046875
# 55       0.832652  0.313320  0.021376        0.263889        0.054688
# 56       0.827860  0.319226  0.025054        0.277778        0.062500
# ...
